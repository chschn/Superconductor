# %% [markdown]
# # Hyperparameter optimization for Decision Tree

# %% [markdown]
# ## Importing the required modules

# %%
import time
import numpy as np
import pandas as pd
from util import read_train_test
from hypopt import treehyp

# %% [markdown]
# ## Registering the start time for runtime calculation

# %%
start = time.time()

# %% [markdown]
# ## Reading the training and test data from file

# %%
x_train, x_test, y_train, y_test = read_train_test('../data/sup_dedup_norm_red_tr.csv', '../data/sup_dedup_norm_red_te.csv')

# %% [markdown]
# ## Hyperparameter optimization - Decision Tree

# %%
max_depth_tr_opt, min_samples_tr_opt, rmse_tr = treehyp(x_train, x_test, y_train, y_test, max_depth_min=1, max_depth_max=201, max_depth_n=101, min_samples_min=2, min_samples_max=102, min_samples_n=101, outfile_log='../hyper/hyperlog_dt.txt', outfile_dat='../hyper/hyperdata_dt.csv', outfile_fig='../hyper/hypergraph_dt.jpg')
# Out:
# max_depth = 1.0, min_samples = 2.0, rmse_tr = 24.7502
# max_depth = 1.0, min_samples = 12.0, rmse_tr = 24.7502
# max_depth = 1.0, min_samples = 22.0, rmse_tr = 24.7502
# max_depth = 1.0, min_samples = 32.0, rmse_tr = 24.7502
# max_depth = 1.0, min_samples = 42.0, rmse_tr = 24.7502
# max_depth = 1.0, min_samples = 52.0, rmse_tr = 24.7502
# max_depth = 1.0, min_samples = 62.0, rmse_tr = 24.7502
# max_depth = 1.0, min_samples = 72.0, rmse_tr = 24.7502
# max_depth = 1.0, min_samples = 82.0, rmse_tr = 24.7502
# max_depth = 1.0, min_samples = 92.0, rmse_tr = 24.7502
# max_depth = 1.0, min_samples = 102.0, rmse_tr = 24.7502
# max_depth = 21.0, min_samples = 2.0, rmse_tr = 13.6420
# max_depth = 21.0, min_samples = 12.0, rmse_tr = 13.4842
# max_depth = 21.0, min_samples = 22.0, rmse_tr = 13.4768
# max_depth = 21.0, min_samples = 32.0, rmse_tr = 13.7340
# max_depth = 21.0, min_samples = 42.0, rmse_tr = 14.1120
# max_depth = 21.0, min_samples = 52.0, rmse_tr = 14.5761
# max_depth = 21.0, min_samples = 62.0, rmse_tr = 14.7883
# max_depth = 21.0, min_samples = 72.0, rmse_tr = 15.0118
# max_depth = 21.0, min_samples = 82.0, rmse_tr = 15.2522
# max_depth = 21.0, min_samples = 92.0, rmse_tr = 15.3304
# max_depth = 21.0, min_samples = 102.0, rmse_tr = 15.3894
# max_depth = 41.0, min_samples = 2.0, rmse_tr = 14.0513
# max_depth = 41.0, min_samples = 12.0, rmse_tr = 13.5293
# max_depth = 41.0, min_samples = 22.0, rmse_tr = 13.5431
# max_depth = 41.0, min_samples = 32.0, rmse_tr = 13.6741
# max_depth = 41.0, min_samples = 42.0, rmse_tr = 14.1603
# max_depth = 41.0, min_samples = 52.0, rmse_tr = 14.5317
# max_depth = 41.0, min_samples = 62.0, rmse_tr = 14.7397
# max_depth = 41.0, min_samples = 72.0, rmse_tr = 15.0478
# max_depth = 41.0, min_samples = 82.0, rmse_tr = 15.2497
# max_depth = 41.0, min_samples = 92.0, rmse_tr = 15.2820
# max_depth = 41.0, min_samples = 102.0, rmse_tr = 15.3723
# max_depth = 61.0, min_samples = 2.0, rmse_tr = 14.0080
# max_depth = 61.0, min_samples = 12.0, rmse_tr = 13.4844
# max_depth = 61.0, min_samples = 22.0, rmse_tr = 13.6008
# max_depth = 61.0, min_samples = 32.0, rmse_tr = 13.6354
# max_depth = 61.0, min_samples = 42.0, rmse_tr = 13.9647
# max_depth = 61.0, min_samples = 52.0, rmse_tr = 14.5686
# max_depth = 61.0, min_samples = 62.0, rmse_tr = 14.7836
# max_depth = 61.0, min_samples = 72.0, rmse_tr = 15.0483
# max_depth = 61.0, min_samples = 82.0, rmse_tr = 15.2458
# max_depth = 61.0, min_samples = 92.0, rmse_tr = 15.2820
# max_depth = 61.0, min_samples = 102.0, rmse_tr = 15.3893
# max_depth = 81.0, min_samples = 2.0, rmse_tr = 13.7666
# max_depth = 81.0, min_samples = 12.0, rmse_tr = 13.3334
# max_depth = 81.0, min_samples = 22.0, rmse_tr = 13.5569
# max_depth = 81.0, min_samples = 32.0, rmse_tr = 13.7307
# max_depth = 81.0, min_samples = 42.0, rmse_tr = 14.1105
# max_depth = 81.0, min_samples = 52.0, rmse_tr = 14.5850
# max_depth = 81.0, min_samples = 62.0, rmse_tr = 14.7329
# max_depth = 81.0, min_samples = 72.0, rmse_tr = 15.0052
# max_depth = 81.0, min_samples = 82.0, rmse_tr = 15.2072
# max_depth = 81.0, min_samples = 92.0, rmse_tr = 15.3243
# max_depth = 81.0, min_samples = 102.0, rmse_tr = 15.3753
# max_depth = 101.0, min_samples = 2.0, rmse_tr = 13.4821
# max_depth = 101.0, min_samples = 12.0, rmse_tr = 13.5195
# max_depth = 101.0, min_samples = 22.0, rmse_tr = 13.5850
# max_depth = 101.0, min_samples = 32.0, rmse_tr = 13.7578
# max_depth = 101.0, min_samples = 42.0, rmse_tr = 13.9586
# max_depth = 101.0, min_samples = 52.0, rmse_tr = 14.5399
# max_depth = 101.0, min_samples = 62.0, rmse_tr = 14.7322
# max_depth = 101.0, min_samples = 72.0, rmse_tr = 15.0522
# max_depth = 101.0, min_samples = 82.0, rmse_tr = 15.2033
# max_depth = 101.0, min_samples = 92.0, rmse_tr = 15.3277
# max_depth = 101.0, min_samples = 102.0, rmse_tr = 15.3893
# max_depth = 121.0, min_samples = 2.0, rmse_tr = 13.7685
# max_depth = 121.0, min_samples = 12.0, rmse_tr = 13.4978
# max_depth = 121.0, min_samples = 22.0, rmse_tr = 13.6901
# max_depth = 121.0, min_samples = 32.0, rmse_tr = 13.7353
# max_depth = 121.0, min_samples = 42.0, rmse_tr = 14.0157
# max_depth = 121.0, min_samples = 52.0, rmse_tr = 14.5317
# max_depth = 121.0, min_samples = 62.0, rmse_tr = 14.7322
# max_depth = 121.0, min_samples = 72.0, rmse_tr = 15.0092
# max_depth = 121.0, min_samples = 82.0, rmse_tr = 15.2033
# max_depth = 121.0, min_samples = 92.0, rmse_tr = 15.3277
# max_depth = 121.0, min_samples = 102.0, rmse_tr = 15.3723
# max_depth = 141.0, min_samples = 2.0, rmse_tr = 13.9966
# max_depth = 141.0, min_samples = 12.0, rmse_tr = 13.6181
# max_depth = 141.0, min_samples = 22.0, rmse_tr = 13.6519
# max_depth = 141.0, min_samples = 32.0, rmse_tr = 13.6984
# max_depth = 141.0, min_samples = 42.0, rmse_tr = 14.1667
# max_depth = 141.0, min_samples = 52.0, rmse_tr = 14.5842
# max_depth = 141.0, min_samples = 62.0, rmse_tr = 14.7836
# max_depth = 141.0, min_samples = 72.0, rmse_tr = 15.0483
# max_depth = 141.0, min_samples = 82.0, rmse_tr = 15.2458
# max_depth = 141.0, min_samples = 92.0, rmse_tr = 15.3277
# max_depth = 141.0, min_samples = 102.0, rmse_tr = 15.3863
# max_depth = 161.0, min_samples = 2.0, rmse_tr = 14.2238
# max_depth = 161.0, min_samples = 12.0, rmse_tr = 13.4836
# max_depth = 161.0, min_samples = 22.0, rmse_tr = 13.7191
# max_depth = 161.0, min_samples = 32.0, rmse_tr = 13.7036
# max_depth = 161.0, min_samples = 42.0, rmse_tr = 14.1085
# max_depth = 161.0, min_samples = 52.0, rmse_tr = 14.5304
# max_depth = 161.0, min_samples = 62.0, rmse_tr = 14.7364
# max_depth = 161.0, min_samples = 72.0, rmse_tr = 15.0052
# max_depth = 161.0, min_samples = 82.0, rmse_tr = 15.2458
# max_depth = 161.0, min_samples = 92.0, rmse_tr = 15.2820
# max_depth = 161.0, min_samples = 102.0, rmse_tr = 15.3753
# max_depth = 181.0, min_samples = 2.0, rmse_tr = 13.8351
# max_depth = 181.0, min_samples = 12.0, rmse_tr = 13.4891
# max_depth = 181.0, min_samples = 22.0, rmse_tr = 13.7075
# max_depth = 181.0, min_samples = 32.0, rmse_tr = 13.6983
# max_depth = 181.0, min_samples = 42.0, rmse_tr = 14.0202
# max_depth = 181.0, min_samples = 52.0, rmse_tr = 14.5714
# max_depth = 181.0, min_samples = 62.0, rmse_tr = 14.7815
# max_depth = 181.0, min_samples = 72.0, rmse_tr = 15.0092
# max_depth = 181.0, min_samples = 82.0, rmse_tr = 15.2497
# max_depth = 181.0, min_samples = 92.0, rmse_tr = 15.3277
# max_depth = 181.0, min_samples = 102.0, rmse_tr = 15.3893
# max_depth = 201.0, min_samples = 2.0, rmse_tr = 13.8322
# max_depth = 201.0, min_samples = 12.0, rmse_tr = 13.4068
# max_depth = 201.0, min_samples = 22.0, rmse_tr = 13.4955
# max_depth = 201.0, min_samples = 32.0, rmse_tr = 13.6743
# max_depth = 201.0, min_samples = 42.0, rmse_tr = 14.1647
# max_depth = 201.0, min_samples = 52.0, rmse_tr = 14.5188
# max_depth = 201.0, min_samples = 62.0, rmse_tr = 14.7877
# max_depth = 201.0, min_samples = 72.0, rmse_tr = 15.0483
# max_depth = 201.0, min_samples = 82.0, rmse_tr = 15.2072
# max_depth = 201.0, min_samples = 92.0, rmse_tr = 15.2854
# max_depth = 201.0, min_samples = 102.0, rmse_tr = 15.3863
# Optimum point with RMSE = 13.3334 found at [81.0, 12.0]

# %% [markdown]
# ## Output of elapsed time

# %%
end = time.time()
runtime = end - start
print(f"Runtime = {runtime:.2f} s")
# Out:
# Runtime = 12.73 s
